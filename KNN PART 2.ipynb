# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot  as plt

# %%
data=pd.read_csv('F:/PythonML/Python Datasets/Classification Datasets/Social_Network_Ads.csv')

# %%
data.head(10)
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0
# 5  15728773    Male   27            58000          0
# 6  15598044  Female   27            84000          0
# 7  15694829  Female   32           150000          1
# 8  15600575    Male   25            33000          0
# 9  15727311  Female   35            65000          0

# %%
data.iloc[:,2:4]
#require 2 columns age and salary from my given data frame
# Out:
#      Age  EstimatedSalary
# 0     19            19000
# 1     35            20000
# 2     26            43000
# 3     27            57000
# 4     19            76000
# ..   ...              ...
# 395   46            41000
# 396   51            23000
# 397   50            20000
# 398   36            33000
# 399   49            36000
#
# [400 rows x 2 columns]

# %%
#
data.iloc[:,2:4].values#in the form of numpy arrays
# Out:
# array([[    19,  19000],
#        [    35,  20000],
#        [    26,  43000],
#        [    27,  57000],
#        [    19,  76000],
#        [    27,  58000],
#        [    27,  84000],
#        [    32, 150000],
#        [    25,  33000],
#        [    35,  65000],
#        [    26,  80000],
#        [    26,  52000],
#        [    20,  86000],
#        [    32,  18000],
#        [    18,  82000],
#        [    29,  80000],
#        [    47,  25000],
#        [    45,  26000],
#        [    46,  28000],
#        [    48,  29000],
#        [    45,  22000],
#        [    47,  49000],
#        [    48,  41000],
#        [    45,  22000],
#        [    46,  23000],
#        [    47,  20000],
#        [    49,  28000],
#        [    47,  30000],
#        [    29,  43000],
#        [    31,  18000],
#        [    31,  74000],
#        [    27, 137000],
#        [    21,  16000],
#        [    28,  44000],
#        [    27,  90000],
#        [    35,  27000],
#        [    33,  28000],
# ...

# %%
# x as input these 2 columns converted into numpy array store in capital x
X=data.iloc[:,2:4].values

# %%
#400 row and 2 columns
X.shape
# Out:
# (400, 2)

# %%
#use output variable is fron last columens
Y=data.iloc[:,-1].values

# %%
Y.shape
# Out:
# (400,)

# %%
# divide the data into training and test for cross validation for model slection
#create 4 variables from model slection
from sklearn.model_selection import train_test_split #split data ito training and testing the data

# %%
# only 20% test data remaining data for training data
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.20)

# %%
X.shape
# Out:
# (400, 2)

# %%
# this data for training data
X_train.shape
# Out:
# (320, 2)

# %%
#this data for test data
X_test.shape
# Out:
# (80, 2)

# %%
#find out distance between 2 point fromm 2 columns very large diff bet age and salary thats why we use 
#class sklearn liabry craete object standardscaler class
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()

# %%
#this is my age columns and estimated salry columns
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.74263301,  0.53700389],
#        [-0.26886395, -0.88684899],
#        [-1.12164827,  0.32935868],
#        [ 0.48916656,  1.27859393],
#        [-1.02689445,  0.62599469],
#        [-1.12164827, -1.0944942 ],
#        [ 0.773428  , -0.29357696],
#        [ 1.24719707, -1.36146662],
#        [-0.26886395, -0.56054937],
#        [-1.02689445, -0.32324056],
#        [ 0.86818182,  1.30825753],
#        [-1.21640208,  0.29969508],
#        [-1.50066352, -0.41223136],
#        [-0.83738683, -0.23424975],
#        [-0.6478792 , -0.32324056],
#        [-0.74263301, -0.59021297],
#        [-1.12164827, -1.1538214 ],
#        [-0.36361776,  1.36758473],
#        [ 0.39441275,  0.29969508],
#        [ 1.05768944, -1.21314861],
#        [ 0.39441275, -0.11559535],
#        [ 1.4367047 ,  0.09204986],
#        [ 1.05768944,  0.15137707],
#        [-1.31115589, -0.32324056],
#        [ 0.67867419, -1.39113022],
#        [-1.12164827, -1.56911183],
#        [-1.50066352, -1.50978462],
# ...

# %%
X_test=scaler.fit_transform(X_test)
X_test
# Out:
# array([[-1.77575914, -0.0888028 ],
#        [-0.28976823, -0.85605902],
#        [-0.58696641,  1.27520825],
#        [-0.48790035,  1.33204204],
#        [ 0.30462814,  0.96262238],
#        [ 0.00742995,  1.81512929],
#        [ 1.79061905,  1.61621101],
#        [ 0.99809056, -1.50964765],
#        [-1.57762702, -0.1456366 ],
#        [ 0.30462814, -0.45822246],
#        [ 1.09715663, -1.14022799],
#        [-0.48790035,  1.7582955 ],
#        [ 0.50276026, -0.25930418],
#        [-1.18136278, -1.45281385],
#        [ 1.09715663,  1.92879688],
#        [ 0.50276026,  0.19536617],
#        [-0.09163611,  2.01404757],
#        [-1.77575914, -1.48123075],
#        [ 0.30462814, -0.03196901],
#        [ 0.50276026, -0.0888028 ],
#        [ 0.79995844, -1.16864489],
#        [ 0.50276026,  0.99103928],
#        [ 1.69155299,  0.99103928],
#        [ 0.50276026,  2.15613205],
#        [ 0.99809056, -0.62872384],
#        [-1.57762702,  0.42270134],
#        [-0.19070217, -0.51505626],
# ...

# %%
# 1st method is squareroot of 
np.sqrt(X_train.shape[0])
# Out:
# 17.88854381999832

# %%
# assume value of k is 17
k=17

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=k)

# %%
# train our model
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=17, p=2,
#                      weights='uniform')

# %%
y_predict1=knn.predict(X_test)

# %%
y_predict1.shape
# Out:
# (80,)

# %%
Y_test.shape
# Out:
# (80,)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_test,y_predict1)
# Out:
# 0.8875

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(Y_test,y_predict1)
# Out:
# array([[44,  6],
#        [ 3, 27]], dtype=int64)

# %%
#using 2nd method

# %%
accuracy=[]
for i in range (1,26):
    knn=KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train,Y_train)
    accuracy.append(accuracy_score(Y_test,knn.predict(X_test)))

# %%
len(accuracy)
# Out:
# 25

# %%
plt.plot(range(1,26),accuracy)

# %%
knn=KNeighborsClassifier(n_neighbors=11)
knn.fit(X_train,Y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=11, p=2,
#                      weights='uniform')

# %%
y_pred=knn.predict(X_test)

# %%
accuracy_score(Y_test,y_pred)
# Out:
# 0.8875

# %%
 import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot  as plt

# %%
from sklearn import svm

# %%
from sklearn.datasets.samples_generator import make_blobs

# %%
X,y=make_blobs(n_samples=40,centers=2,random_state=20)

# %%
clf=svm.SVC(kernel='linear',C=1)

# %%
clf.fit(X,y)
# Out:
# SVC(C=1, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#     kernel='linear', max_iter=-1, probability=False, random_state=None,
#     shrinking=True, tol=0.001, verbose=False)

# %%
plt.scatter(X[:,0],X[:,1],c=y,s=30,cmap=plt.cm.Paired)
plt.show()
